# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

from ROOT import TH1D, TCanvas, TF1
from ROOT import gStyle
from numpy.random import normal, poisson
c1 = TCanvas('c1', 'Python Example', 200, 10, 700, 500)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
# Varibles for the gaussian
num = 100000
mean = 0.95
sigma = 0.05

# Define the histogram to fill
hist = TH1D("hist", "Gaussian", 200, 0.0, 2.0)
# Define the gui to display the graph and set the display options

gStyle.SetOptStat(111)
gStyle.SetOptFit(111)

# Thrown a normal(gaussian) distobution using numpy
throw = normal(loc=mean, scale=sigma, size=num)
throw2 = normal(loc=1.1, scale=1.0, size=num*50)
# Loop over the thrown event and fill in histogram
#for t in throw:
#    hist.Fill(t)
# Same as above but in one line
[hist.Fill(t) for t in throw]
[hist.Fill(t) for t in throw2]

# Enter the canvas to draw
c1.cd()
# Draw histogram in gui
hist.Draw()
# Fit gaussian to the histogram
hist.Fit("gaus")
c1.Update()
c1.Draw()
# Out:
#  FCN=17718.7 FROM MIGRAD    STATUS=CONVERGED      91 CALLS          92 TOTAL
#                      EDM=1.64672e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     2.09018e+04   1.60501e+01   7.27884e-01  -5.13694e-05
#    2  Mean         1.08235e+00   8.96339e-04   5.57597e-05  -1.28286e+00
#    3  Sigma        9.26212e-01   1.55739e-03   3.39645e-05   1.28642e+00
# Warning in <TROOT::Append>: Replacing existing TH1: hist (Potential memory leak).

# %%
#plt.hist(throw2,200,density=True)
#plt.hist(throw,200,density=True)
plt.hist(np.concatenate((throw, throw2)),200,(0,2))
plt.show()
